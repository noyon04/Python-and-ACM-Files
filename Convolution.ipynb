# %%
import numpy as np
from PIL import Image

# %%
x=[[0,2,200,87],[77,220,0,29],[5,60,1,0],[0,3,70,99]]

# %%
x=np.array(x)
sobel=[[-1,2,-1],[0,0,0],[1,2,1]]
sobel=np.array(sobel)

# %%
x = np.insert(x, len(x), 0, axis = 0)
x = np.insert(x, 0, 0, axis = 1)
x = np.insert(x, 0, 0, axis = 0)
x = np.insert(x, len(x)-1, 0, axis = 1)

# %%
x=[[0,0,70,-80,5,0],[-20,-30,100,100,-10,5],[0,0,-90,140,20,-5],[0,0,130,160,-12,5],[-50,150,170,180,-160,140],[2,0,0,5,11,0]]

# %%
x
# Out:
# array([[   0,    0,   70,  -80,    5,    0],
#        [ -20,  -30,  100,  100,  -10,    5],
#        [   0,    0,  -90,  140,   20,   -5],
#        [   0,    0,  130,  160,  -12,    5],
#        [ -50,  150,  170,  180, -160,  140],
#        [   2,    0,    0,    5,   11,    0]])

# %%
temp=0
temp2=[]
conv=[]
for i in range(len(x)-2):
    for j in range(len(x)-2):
        for k in range(len(sobel)):
            for l in range(len(sobel)):
                temp=temp+x[k+i][l+j]*sobel[k][l]
        temp2.append(temp)
        #conv.append(temp)
        temp=0
    conv.append(temp2)
    temp2=[]

# %%
conv
# Out:
# [[0, 180, 0, 265], [0, 550, 548, 16], [510, 350, 720, 0], [0, 105, 223, 0]]

# %%
def relu(arr):
    for i in range(len(arr)):
        for j in range(len(arr)):
            if(arr[i][j]<0):
                arr[i][j]=0
    return arr

# %%
conv=relu(conv)

# %%
conv=np.array(conv)

# %%
k=conv[0:2,0:2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a6eba3142777> in <module>
# ----> 1 k=conv[0:2,0:2]
#       2 print(conv[0:2,0:2])
#
# NameError: name 'conv' is not defined

# %%
np.amax(k)
# Out:
# 517

# %%
np.shape(conv)
# Out:
# (4, 4)

# %%
try:  
        img = Image.open("image.png").convert('L')
        width, height = img.size
except IOError: 
        pass

# %%
img
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x2347F6EC438>

# %%
from numpy import asarray
x=asarray(img)

# %%
x
# Out:
# array([[160, 161, 162, ..., 169, 155, 128],
#        [160, 160, 162, ..., 170, 156, 126],
#        [160, 160, 161, ..., 170, 157, 126],
#        ...,
#        [ 43,  36,  54, ..., 102,  98,  98],
#        [ 44,  39,  60, ..., 104, 106, 104],
#        [ 46,  40,  61, ..., 102, 109, 108]], dtype=uint8)

# %%
print(x.shape)
# Out:
# (512, 512)

# %%
image2 = Image.fromarray(conv)
print(type(image2))
# Out:
# <class 'PIL.Image.Image'>

# %%
image2
# Out:
# <PIL.Image.Image image mode=I size=4x4 at 0x268671FB748>
